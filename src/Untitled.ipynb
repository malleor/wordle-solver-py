# %%
with open('../res/valid_guesses.csv', 'rt') as f:
    d = f.readlines()
d = [w[:-1] for w in d]

# %%
stat = pd.DataFrame(0, index=list(string.ascii_lowercase), columns=[0,1,2,3,4])
for w in d:
    for i in range(5):
        stat.loc[w[i]][i] += 1

# %%
stat
# Out:
#       0     1     2     3     4
# a   596  1959   929   911   616
# b   736    65   278   219    48
# c   724   136   336   259    96
# d   574    64   315   402   705
# e   231  1386   705  2009  1098
# f   462    16   153   198    56
# g   523    64   297   347   102
# h   420   402   111   207   231
# i   131  1181   785   722   269
# j   182     9    43    27     3
# k   356    85   260   448   146
# l   489   498   736   609   320
# m   586   150   450   334   140
# n   288   258   825   606   400
# o   221  1817   749   566   331
# p   717   170   306   368    91
# q    55    10    12     2     4
# r   523   673  1035   567   461
# s  1199    77   453   345  3922
# t   666   162   505   759   474
# u   156  1001   502   319    66
# v   199    37   191   110     4
# w   330   119   245   103    47
# x    16    43   121     9    62
# y   175   248   184   105   937
# z   102    27   131   106    28

# %%
scores = [(w, sum([stat.loc[w[i]][i] for i in range(5)])) for w in d]

# %%
sorted(scores, key=lambda x: -x[1])
# Out:
# [('sores', 9982),
#  ('sanes', 9914),
#  ('sales', 9825),
#  ('sones', 9772),
#  ('soles', 9683),
#  ('bares', 9661),
#  ('cares', 9649),
#  ('pares', 9642),
#  ('sates', 9594),
#  ('tares', 9591),
#  ('seres', 9551),
#  ('sames', 9539),
#  ('bores', 9519),
#  ('mares', 9511),
#  ('cores', 9507),
#  ('pores', 9500),
#  ('dares', 9499),
#  ('banes', 9451),
#  ('tores', 9449),
#  ('gares', 9448),
#  ('rares', 9448),
#  ('canes', 9439),
#  ('panes', 9432),
#  ('lares', 9414),
#  ('sades', 9404),
#  ('fares', 9387),
#  ('sages', 9386),
#  ('mores', 9369),
#  ('sabes', 9367),
#  ('bales', 9362),
#  ('dores', 9357),
#  ('sakes', 9349),
#  ('sires', 9346),
#  ('hares', 9345),
#  ('pales', 9343),
#  ('senes', 9341),
#  ('bones', 9309),
#  ('gores', 9306),
#  ('rores', 9306),
#  ('manes', 9301),
#  ('cones', 9297),
#  ('tales', 9292),
#  ('pones', 9290),
#  ('soces', 9283),
#  ('saves', 9280),
#  ('lores', 9272),
#  ('wares', 9255),
#  ('seles', 9252),
#  ('fores', 9245),
#  ('safes', 9242),
#  ('tones', 9239),
#  ('boles', 9220),
#  ('sazes', 9220),
#  ('nares', 9213),
#  ('males', 9212),
#  ('saxes', 9210),
#  ('coles', 9208),
#  ('sokes', 9207),
#  ('lanes', 9204),
#  ('poles', 9201),
#  ('dales', 9200),
#  ('fanes', 9177),
#  ('sures', 9166),
#  ('toles', 9150),
#  ('gales', 9149),
#  ('rales', 9149),
#  ('kores', 9139),
#  ('sines', 9136),
#  ('bates', 9131),
#  ('vares', 9124),
#  ('cates', 9119),
#  ('pates', 9112),
#  ('rones', 9096),
#  ('beres', 9088),
#  ('bases', 9079),
#  ('ceres', 9076),
#  ('kanes', 9071),
#  ('moles', 9070),
#  ('peres', 9069),
#  ('cases', 9067),
#  ('cames', 9064),
#  ('tates', 9061),
#  ('pases', 9060),
#  ('doles', 9058),
#  ('siles', 9047),
#  ('hales', 9046),
#  ('wanes', 9045),
#  ('fones', 9035),
#  ('kaies', 9031),
#  ('teres', 9018),
#  ('tases', 9009),
#  ('goles', 9007),
#  ('roles', 9007),
#  ('tames', 9006),
#  ('hones', 8993),
#  ('botes', 8989),
#  ('kales', 8982),
#  ('mates', 8981),
#  ('cotes', 8977),
#  ('potes', 8970),
#  ('dates', 8969),
#  ('semes', 8966),
#  ('yores', 8958),
#  ('wales', 8956),
#  ('paces', 8943),
#  ('meres', 8938),
#  ('cades', 8929),
#  ('mases', 8929),
#  ('deres', 8926),
#  ('coses', 8925),
#  ('comes', 8922),
#  ('capes', 8920),
#  ('totes', 8919),
#  ('gates', 8918),
#  ('poses', 8918),
#  ('rates', 8918),
#  ('pomes', 8915),
#  ('dames', 8914),
#  ('vanes', 8914),
#  ('papes', 8913),
#  ('cages', 8911),
#  ('babes', 8904),
#  ('holes', 8904),
#  ('pages', 8904),
#  ('janes', 8897),
#  ('taces', 8892),
#  ('bakes', 8886),
#  ('soras', 8884),
#  ('benes', 8878),
#  ('geres', 8875),
#  ('cakes', 8874),
#  ('cires', 8871),
#  ('toses', 8867),
#  ('gases', 8866),
#  ('rases', 8866),
#  ('tomes', 8864),
#  ('games', 8863),
#  ('tapes', 8862),
#  ('nones', 8861),
#  ('penes', 8859),
#  ('eales', 8857),
#  ('fates', 8857),
#  ('leres', 8841),
#  ('motes', 8839),
#  ('saris', 8837),
#  ('moues', 8836),
#  ('tabes', 8834),
#  ('lases', 8832),
#  ('sedes', 8831),
#  ('lames', 8829),
#  ('dotes', 8827),
#  ('vales', 8825),
#  ('sites', 8816),
#  ('takes', 8816),
#  ('hates', 8815),
#  ('feres', 8814),
#  ('tires', 8813),
#  ('maces', 8812),
#  ('bayes', 8810),
#  ('tenes', 8808),
#  ('caves', 8805),
#  ('fames', 8802),
#  ('yales', 8801),
#  ('daces', 8800),
#  ('bodes', 8799),
#  ('paves', 8798),
#  ('codes', 8787),
#  ('moses', 8787),
#  ('momes', 8784),
#  ('copes', 8778),
#  ('rotes', 8776),
#  ('doses', 8775),
#  ('mages', 8773),
#  ('roues', 8773),
#  ('domes', 8772),
#  ('heres', 8772),
#  ('noles', 8772),
#  ('popes', 8771),
#  ('peles', 8770),
#  ('cafes', 8767),
#  ('sises', 8764),
#  ('hames', 8760),
#  ('jones', 8755),
#  ('mabes', 8754),
#  ('races', 8749),
#  ('bokes', 8744),
#  ('lotes', 8742),
#  ('makes', 8736),
#  ('mires', 8733),
#  ('cokes', 8732),
#  ('sorts', 8732),
#  ('bowes', 8729),
#  ('gades', 8728),
#  ('menes', 8728),
#  ('paxes', 8728),
#  ('pokes', 8725),
#  ('roses', 8724),
#  ('topes', 8720),
#  ('gapes', 8719),
#  ('rapes', 8719),
#  ('teles', 8719),
#  ('denes', 8716),
#  ('laces', 8715),
#  ('toges', 8711),
#  ('gages', 8710),
#  ('rages', 8710),
#  ('kames', 8696),
#  ('lades', 8694),
#  ('cures', 8691),
#  ('loses', 8690),
#  ('faces', 8688),
#  ('lomes', 8687),
#  ('pures', 8684),
#  ('nates', 8683),
#  ('voles', 8683),
#  ('saros', 8681),
#  ('taxes', 8677),
#  ('zones', 8675),
#  ('tokes', 8674),
#  ('bines', 8673),
#  ('rakes', 8673),
#  ('wases', 8673),
#  ('wames', 8670),
#  ('fades', 8667),
#  ('joles', 8666),
#  ('genes', 8665),
#  ('sants', 8664),
#  ('coves', 8663),
#  ('cines', 8661),
#  ('fomes', 8660),
#  ('pines', 8654),
#  ('modes', 8649),
#  ('sices', 8647),
#  ('mopes', 8640),
#  ('lakes', 8639),
#  ('sexes', 8637),
#  ('lenes', 8631),
#  ('dopes', 8628),
#  ('names', 8628),
#  ('deles', 8627),
#  ('sides', 8626),
#  ('hades', 8625),
#  ('hoses', 8621),
#  ('doges', 8619),
#  ('homes', 8618),
#  ('sipes', 8617),
#  ('fakes', 8612),
#  ('mobes', 8612),
#  ('fires', 8609),
#  ('mazes', 8607),
#  ('boxes', 8605),
#  ('raves', 8604),
#  ('cozes', 8603),
#  ('tines', 8603),
#  ('dobes', 8600),
#  ('tajes', 8599),
#  ('maxes', 8597),
#  ('dazes', 8595),
#  ('mokes', 8594),
#  ('coxes', 8593),
#  ('poxes', 8586),
#  ('rodes', 8586),
#  ('solas', 8585),
#  ('biles', 8584),
#  ('suses', 8584),
#  ('sorns', 8579),
#  ('ropes', 8577),
#  ('salts', 8575),
#  ('eases', 8574),
#  ('sikes', 8571),
#  ('hakes', 8570),
#  ('laves', 8570),
#  ('yates', 8570),
#  ('hires', 8567),
#  ('piles', 8565),
#  ('oases', 8564),
#  ('aures', 8563),
#  ('sarks', 8563),
#  ('kades', 8561),
#  ('betes', 8558),
#  ('koses', 8557),
#  ('slaes', 8557),
#  ('mures', 8553),
#  ('lodes', 8552),
#  ('robes', 8549),
#  ('cetes', 8546),
#  ('tozes', 8545),
#  ('gazes', 8544),
#  ('paras', 8544),
#  ('razes', 8544),
#  ('faves', 8543),
#  ('lopes', 8543),
#  ('vases', 8542),
#  ('dures', 8541),
#  ('notes', 8541),
#  ('wades', 8535),
#  ('loges', 8534),
#  ('raxes', 8534),
#  ('rokes', 8531),
#  ('moves', 8525),
#  ('mines', 8523),
#  ('james', 8522),
#  ('sards', 8517),
#  ('wages', 8517),
#  ('lobes', 8515),
#  ('tiles', 8514),
#  ('doves', 8513),
#  ('dines', 8511),
#  ('lazes', 8510),
#  ('beses', 8506),
#  ('haves', 8501),
#  ('laxes', 8500),
#  ('lokes', 8497),
#  ('taras', 8493),
#  ('noses', 8489),
#  ('tetes', 8488),
#  ('nomes', 8486),
#  ('napes', 8484),
#  ('fazes', 8483),
#  ('lowes', 8482),
#  ('wakes', 8480),
#  ('wires', 8477),
#  ('hopes', 8474),
#  ('sails', 8474),
#  ('faxes', 8473),
#  ('heles', 8473),
#  ('sains', 8471),
#  ('mozes', 8465),
#  ('wawes', 8465),
#  ('roves', 8462),
#  ('rines', 8460),
#  ('lures', 8456),
#  ('nabes', 8456),
#  ('rajes', 8456),
#  ('dozes', 8453),
#  ('votes', 8452),
#  ('soots', 8446),
#  ('doxes', 8443),
#  ('sizes', 8442),
#  ('hazes', 8441),
#  ('samas', 8441),
#  ('supes', 8437),
#  ('miles', 8434),
#  ('sarus', 8434),
#  ('soars', 8434),
#  ('temes', 8433),
#  ('sairs', 8432),
#  ('sixes', 8432),
#  ('nenes', 8430),
#  ('hokes', 8428),
#  ('loves', 8428),
#  ('lines', 8426),
#  ('tunes', 8423),
#  ('ooses', 8422),
#  ('boras', 8421),
#  ('howes', 8413),
#  ('maras', 8413),
#  ('waves', 8411),
#  ('metes', 8408),
#  ('vades', 8404),
#  ('carts', 8399),
#  ('fines', 8399),
#  ('vapes', 8395),
#  ('goxes', 8392),
#  ('parts', 8392),
#  ('jades', 8387),
#  ('pules', 8385),
#  ('rohes', 8382),
#  ('japes', 8378),
#  ('sloes', 8377),
#  ('sords', 8375),
#  ('riles', 8371),
#  ('naves', 8369),
#  ('bedes', 8368),
#  ('yages', 8362),
#  ('hoves', 8359),
#  ('loxes', 8358),
#  ('cedes', 8356),
#  ('meses', 8356),
#  ('saags', 8356),
#  ('paris', 8355),
#  ('aunes', 8353),
#  ('bites', 8353),
#  ('hajes', 8353),
#  ('memes', 8353),
#  ('nodes', 8351),
#  ('toras', 8351),
#  ('pedes', 8349),
#  ('cepes', 8347),
#  ('vires', 8346),
#  ('cites', 8341),
#  ('demes', 8341),
#  ('sauts', 8341),
#  ('tarts', 8341),
#  ('waxes', 8341),
#  ('tules', 8334),
#  ('jakes', 8332),
#  ('soils', 8332),
#  ('dunes', 8331),
#  ('foxes', 8331),
#  ('shies', 8317),
#  ('soaks', 8315),
#  ('eaves', 8312),
#  ('files', 8310),
#  ('nazes', 8309),
#  ('sands', 8307),
#  ('satis', 8307),
#  ('oaves', 8302),
#  ('bises', 8301),
#  ('somas', 8299),
#  ('sools', 8296),
#  ('pekes', 8294),
#  ('kines', 8293),
#  ('reses', 8293),
#  ('sorus', 8292),
#  ('hoxes', 8289),
#  ('sagas', 8288),
#  ('fetes', 8284),
#  ('tanas', 8283),
#  ('voces', 8283),
#  ('pises', 8282),
#  ('shoes', 8281),
#  ('runes', 8280),
#  ('moras', 8271),
#  ('borts', 8269),
#  ('braes', 8269),
#  ('saids', 8267),
#  ('wines', 8267),
#  ('balas', 8264),
#  ('marts', 8261),
#  ('leses', 8259),
#  ('barns', 8258),
#  ('lemes', 8256),
#  ('mules', 8254),
#  ('sangs', 8252),
#  ('veles', 8252),
#  ('ports', 8250),
#  ('carls', 8249),
#  ('darts', 8249),
#  ('carns', 8246),
#  ('lunes', 8246),
#  ('palas', 8245),
#  ('senas', 8243),
#  ('dules', 8242),
#  ('hetes', 8242),
#  ('solos', 8240),
#  ('soaps', 8235),
#  ('femes', 8229),
#  ('spaes', 8229),
#  ('aedes', 8228),
#  ('times', 8228),
#  ('nines', 8225),
#  ('noyes', 8220),
#  ('daris', 8212),
#  ('vaxes', 8210),
#  ('goras', 8208),
#  ('jobes', 8208),
#  ('carrs', 8207),
#  ('manas', 8203),
#  ('mites', 8203),
#  ('synes', 8203),
#  ('bants', 8201),
#  ('parrs', 8200),
#  ('saims', 8199),
#  ('souts', 8199),
#  ('torts', 8199),
#  ('seats', 8195),
#  ('talas', 8194),
#  ('sorbs', 8192),
#  ('dites', 8191),
#  ('gules', 8191),
#  ('rules', 8191),
#  ('sauls', 8191),
#  ('jokes', 8190),
#  ('cants', 8189),
#  ('tarns', 8188),
#  ('hemes', 8187),
#  ('socas', 8185),
#  ('bezes', 8184),
#  ('bices', 8184),
#  ('salps', 8184),
#  ('karas', 8183),
#  ('yokes', 8183),
#  ('pants', 8182),
#  ('ketes', 8178),
#  ('wiles', 8178),
#  ('butes', 8173),
#  ('snies', 8173),
#  ('debes', 8169),
#  ('yowes', 8168),
#  ('sodas', 8164),
#  ('bides', 8163),
#  ('boats', 8163),
#  ('baits', 8161),
#  ('cutes', 8161),
#  ('garis', 8161),
#  ('noxes', 8157),
#  ('baals', 8155),
#  ('redes', 8155),
#  ('cides', 8151),
#  ('coats', 8151),
#  ('dekes', 8151),
#  ('mises', 8151),
#  ('jures', 8149),
#  ('mimes', 8148),
#  ('taros', 8148),
#  ('gites', 8140),
#  ('ranas', 8140),
#  ('rites', 8140),
#  ('farts', 8137),
#  ('reges', 8137),
#  ('dimes', 8136),
#  ('paals', 8136),
#  ('vines', 8136),
#  ('pipes', 8135),
#  ('sooks', 8135),
#  ('paans', 8133),
#  ('slues', 8130),
#  ('laris', 8127),
#  ('sobas', 8127),
#  ('bibes', 8126),
#  ('bries', 8125),
#  ('saics', 8124),
#  ('bolas', 8122),
#  ('buses', 8121),
#  ('ledes', 8121),
#  ('morts', 8119),
#  ('sadis', 8117),
#  ('feces', 8115),
#  ('naras', 8115),
#  ('malas', 8114),
#  ('tices', 8114),
#  ('cries', 8113),
#  ('zaxes', 8113),
#  ('marls', 8111),
#  ('colas', 8110),
#  ('netes', 8110),
#  ('songs', 8110),
#  ('serrs', 8109),
#  ('bikes', 8108),
#  ('dorts', 8107),
#  ('lanas', 8106),
#  ('lites', 8106),
#  ('pries', 8106),
#  ('horas', 8105),
#  ('corns', 8104),
#  ('texes', 8104),
#  ('leges', 8103),
#  ('puses', 8102),
#  ('barks', 8100),
#  ('oozes', 8100),
#  ('raias', 8100),
#  ('rekes', 8100),
#  ('porns', 8097),
#  ('darns', 8096),
#  ('harts', 8095),
#  ('blaes', 8094),
#  ('meves', 8094),
#  ('snees', 8093),
#  ('tides', 8093),
#  ('sents', 8091),
#  ('taits', 8091),
#  ('pikes', 8089),
#  ('carks', 8088),
#  ('hules', 8088),
#  ('rises', 8088),
#  ('rimes', 8085),
#  ('spies', 8085),
#  ('taals', 8085),
#  ('claes', 8082),
#  ('parks', 8081),
#  ('sties', 8077),
#  ('solds', 8076),
#  ('tiges', 8075),
#  ('doris', 8070),
#  ('suras', 8068),
#  ('sakis', 8062),
#  ('monas', 8061),
#  ('siris', 8059),
#  ('palis', 8056),
#  ('rorts', 8056),
#  ('soops', 8055),
#  ('tries', 8055),
#  ('bards', 8054),
#  ('tolas', 8052),
#  ('galas', 8051),
#  ('limes', 8051),
#  ('donas', 8049),
#  ('souls', 8049),
#  ('banns', 8048),
#  ('brees', 8045),
#  ('seals', 8045),
#  ('cards', 8042),
#  ('seans', 8042),
#  ('koras', 8041),
#  ('ponts', 8040),
#  ('dants', 8039),
#  ('zines', 8039),
#  ('tikes', 8038),
#  ('canns', 8036),
#  ('pards', 8035),
#  ('mezes', 8034),
#  ('swies', 8034),
#  ('crees', 8033),
#  ('soyas', 8033),
#  ('karts', 8031),
#  ('cives', 8027),
#  ('prees', 8026),
#  ('varas', 8026),
#  ('aides', 8023),
#  ('mutes', 8023),
#  ('dices', 8022),
#  ('sooms', 8021),
#  ('toeas', 8021),
#  ('barps', 8020),
#  ('goris', 8019),
#  ('hebes', 8015),
#  ('manis', 8014),
#  ('moats', 8013),
#  ('dexes', 8012),
#  ('bails', 8011),
#  ('larns', 8011),
#  ('pauas', 8011),
#  ('carps', 8008),
#  ('coits', 8007),
#  ('sours', 8007),
#  ('torrs', 8007),
#  ('toros', 8006),
#  ('warts', 8005),
#  ('jetes', 8004),
#  ('sears', 8003),
#  ('sofas', 8002),
#  ('coals', 8001),
#  ('doats', 8001),
#  ('parps', 8001),
#  ('skies', 8000),
#  ('leves', 7997),
#  ('cains', 7996),
#  ('forts', 7995),
#  ('daals', 7993),
#  ('solus', 7993),
#  ('pails', 7992),
#  ('serks', 7990),
#  ('pains', 7989),
#  ('gants', 7988),
#  ('rants', 7988),
#  ('farls', 7987),
#  ('barms', 7986),
#  ('loris', 7985),
#  ('puces', 7985),
#  ('smees', 7985),
#  ('boots', 7983),
#  ('bizes', 7979),
#  ('trees', 7975),
#  ('kanas', 7973),
#  ('kites', 7973),
#  ('molas', 7972),
#  ('boars', 7971),
#  ('coots', 7971),
#  ('muses', 7971),
#  ('rezes', 7971),
#  ('rices', 7971),
#  ('bolts', 7970),
#  ('casas', 7969),
#  ('camas', 7966),
#  ('morns', 7966),
#  ('poots', 7964),
#  ('dries', 7963),
#  ('maars', 7963),
#  ('balls', 7962),
#  ('malts', 7962),
#  ('rexes', 7961),
#  ('sados', 7961),
#  ('pizes', 7960),
#  ('borks', 7958),
#  ('colts', 7958),
#  ('mikes', 7958),
#  ('lants', 7954),
#  ('swees', 7954),
#  ('polts', 7951),
#  ('ranis', 7951),
#  ('byres', 7950),
#  ('calls', 7950),
#  ('dalts', 7950),
#  ('goats', 7950),
#  ('marks', 7950),
#  ('pairs', 7950),
#  ('pixes', 7950),
#  ('rides', 7950),
#  ('tarps', 7950),
#  ('toits', 7949),
#  ('gaits', 7948),
#  ('raits', 7948),
#  ('wites', 7947),
#  ('corks', 7946),
#  ('dikes', 7946),
#  ('harls', 7945),
#  ('yeses', 7945),
#  ('faros', 7944),
#  ('palls', 7943),
#  ('sagos', 7943),
#  ('harns', 7942),
#  ('ripes', 7941),
#  ('tails', 7941),
#  ('boets', 7939),
#  ('porks', 7939),
#  ('clies', 7938),
#  ('darks', 7938),
#  ('tains', 7938),
#  ('lezes', 7937),
#  ('arles', 7936),
#  ('cubes', 7934),
#  ('baels', 7931),
#  ('plies', 7931),
#  ('pyres', 7931),
#  ('bukes', 7928),
#  ('lexes', 7927),
#  ('pubes', 7927),
#  ('lutes', 7926),
#  ('naris', 7926),
#  ('malis', 7925),
#  ('poets', 7920),
#  ('skees', 7920),
#  ('teras', 7920),
#  ('cukes', 7916),
#  ('horis', 7916),
#  ('dorrs', 7915),
#  ('polis', 7914),
#  ('dalis', 7913),
#  ('gibes', 7913),
#  ('ribes', 7913),
#  ('toots', 7913),
#  ('bords', 7912),
#  ('fezes', 7910),
#  ('fices', 7910),
#  ('pukes', 7909),
#  ('tizes', 7909),
#  ('ruses', 7908),
#  ('calos', 7907),
#  ('lipes', 7907),
#  ('nanas', 7905),
#  ('nites', 7905),
#  ('rumes', 7905),
#  ('haros', 7902),
#  ('seils', 7901),
#  ('cords', 7900),
#  ('tolts', 7900),
#  ('samps', 7898),
#  ('wises', 7895),
#  ('conns', 7894),
#  ('sojas', 7892),
#  ('talls', 7892),
#  ('botas', 7891),
#  ('banks', 7890),
#  ('fides', 7889),
#  ('souks', 7888),
#  ('rarks', 7887),
#  ('hants', 7885),
#  ('drees', 7883),
#  ('batts', 7881),
#  ('tyres', 7880),
#  ('karns', 7878),
#  ('dives', 7877),
#  ('tubes', 7876),
#  ('barbs', 7871),
#  ('blees', 7870),
#  ('boils', 7869),
#  ('moits', 7869),
#  ('corps', 7866),
#  ('sacks', 7864),
#  ('worts', 7863),
#  ('likes', 7861),
#  ('mails', 7861),
#  ('taels', 7861),
#  ('moans', 7860),
#  ('carbs', 7859),
#  ('seirs', 7859),
#  ('hexes', 7858),
#  ('mains', 7858),
#  ('manos', 7858),
#  ('coils', 7857),
#  ('doits', 7857),
#  ('coins', 7854),
#  ('larks', 7853),
#  ('boaks', 7852),
#  ('cacas', 7852),
#  ('sells', 7852),
#  ('warns', 7852),
#  ('fries', 7851),
#  ('barfs', 7850),
#  ('softs', 7850),
#  ('margs', 7849),
#  ('fuses', 7847),
#  ('hides', 7847),
#  ('ronts', 7846),
#  ('pacas', 7845),
#  ('bands', 7844),
#  ('borms', 7844),
#  ('fumes', 7844),
#  ('yules', 7843),
#  ('duces', 7842),
#  ('sials', 7840),
#  ('karos', 7838),
#  ('dargs', 7837),
#  ('bomas', 7836),
#  ('marms', 7836),
#  ('fikes', 7834),
#  ('bools', 7833),
#  ('moots', 7833),
#  ('corms', 7832),
#  ('grees', 7832),
#  ('masas', 7831),
#  ('paiks', 7831),
#  ('boons', 7830),
#  ('crues', 7830),
#  ('basts', 7829),
#  ('mamas', 7828),
#  ('certs', 7826),
#  ('gives', 7826),
#  ('rives', 7826),
#  ('pands', 7825),
#  ('comas', 7824),
#  ('capas', 7822),
#  ('cools', 7821),
#  ('dudes', 7821),
#  ('kants', 7821),
#  ('seels', 7821),
#  ('bolls', 7820),
#  ('molts', 7820),
#  ('ratas', 7820),
#  ('tanks', 7820),
#  ('mairs', 7819),
#  ('mixes', 7819),
#  ('perts', 7819),
#  ('coons', 7818),
#  ('casts', 7817),
#  ('nalas', 7816),
#  ('coirs', 7815),
#  ('froes', 7815),
#  ('papas', 7815),
#  ('pools', 7814),
#  ('veges', 7813),
#  ('dupes', 7812),
#  ('malls', 7812),
#  ('poons', 7811),
#  ('tatts', 7811),
#  ('ayres', 7810),
#  ('pasts', 7810),
#  ('colls', 7808),
#  ('dolts', 7808),
#  ('soups', 7808),
#  ('tauts', 7808),
#  ('lards', 7807),
#  ('yedes', 7807),
#  ('babas', 7806),
#  ('spues', 7802),
#  ('balks', 7801),
#  ('polls', 7801),
#  ('goals', 7800),
#  ('horns', 7800),
#  ('toils', 7799),
#  ('rails', 7798),
#  ('haars', 7797),
#  ('roans', 7797),
#  ('silts', 7797),
#  ('dorks', 7796),
#  ('halts', 7796),
#  ('neves', 7796),
#  ('gains', 7795),
#  ('rains', 7795),
#  ('wants', 7795),
#  ('cabas', 7794),
#  ('kexes', 7794),
#  ('caids', 7792),
#  ('hikes', 7792),
#  ('lives', 7792),
#  ('sowls', 7792),
#  ('yites', 7792),
#  ('boors', 7791),
#  ('bangs', 7789),
#  ('calks', 7789),
#  ('cuzes', 7787),
#  ('fonts', 7785),
#  ('harks', 7784),
#  ('noris', 7784),
#  ('peris', 7782),
#  ('fards', 7780),
#  ('seers', 7779),
#  ('bolos', 7777),
#  ('camis', 7777),
#  ('cangs', 7777),
#  ('aloes', 7774),
#  ('kipes', 7774),
#  ('soums', 7774),
#  ('garms', 7773),
#  ('trues', 7772),
#  ('frees', 7771),
#  ('setts', 7771),
#  ('gudes', 7770),
#  ('pangs', 7770),
#  ('roots', 7770),
#  ('rudes', 7770),
#  ('seams', 7770),
#  ('tosas', 7769),
#  ('terts', 7768),
#  ('wexes', 7768),
#  ('dukes', 7766),
#  ('fives', 7765),
#  ('gamas', 7765),
#  ('haets', 7765),
#  ('tapas', 7764),
#  ('vises', 7764),
#  ('loans', 7763),
#  ('nonas', 7763),
#  ('tools', 7763),
#  ('gaols', 7762),
#  ('marcs', 7761),
#  ('toons', 7760),
#  ('polos', 7758),
#  ('roars', 7758),
#  ('luces', 7757),
#  ('wides', 7757),
#  ('earls', 7756),
#  ('gairs', 7756),
#  ('balds', 7755),
#  ('waits', 7755),
#  ('lifes', 7754),
#  ('pawas', 7754),
#  ('earns', 7753),
#  ('tolls', 7750),
#  ('galls', 7749),
#  ('bonks', 7748),
#  ('wipes', 7748),
#  ('kibes', 7746),
#  ('kolas', 7742),
#  ('serfs', 7740),
#  ('zaris', 7740),
#  ('botts', 7739),
#  ('foals', 7739),
#  ('hards', 7738),
#  ('fails', 7737),
#  ('gyres', 7737),
#  ('bouts', 7736),
#  ('conks', 7736),
#  ('loots', 7736),
#  ('ludes', 7736),
#  ('toads', 7736),
#  ('fains', 7734),
#  ('fanos', 7734),
#  ('sends', 7734),
#  ('rubes', 7733),
#  ('apres', 7732),
#  ('beats', 7732),
#  ('lamas', 7731),
#  ('matts', 7731),
#  ('talks', 7731),
#  ('ponks', 7729),
#  ('danks', 7728),
#  ('kikes', 7728),
#  ('mauts', 7728),
#  ('cotts', 7727),
#  ('fifes', 7727),
#  ('hives', 7723),
#  ('lairs', 7722),
#  ('socks', 7722),
#  ('pynes', 7721),
#  ('karks', 7720),
#  ('potts', 7720),
#  ('moils', 7719),
#  ('tamis', 7719),
#  ('tangs', 7719),
#  ('tuxes', 7719),
#  ('wries', 7719),
#  ('luges', 7718),
#  ('takas', 7718),
#  ('pouts', 7717),
#  ('cauls', 7716),
#  ('dauts', 7716),
#  ('dorps', 7716),
#  ('monos', 7716),
#  ('lalls', 7715),
#  ('nides', 7715),
#  ('wuses', 7715),
#  ('macas', 7714),
#  ('syces', 7714),
#  ('peats', 7713),
#  ('farms', 7712),
#  ('cocas', 7710),
#  ('calps', 7709),
#  ('darbs', 7709),
#  ('foots', 7709),
#  ('pauls', 7709),
#  ('cavas', 7707),
#  ('jarls', 7707),
#  ('harps', 7704),
#  ('naans', 7704),
#  ('thees', 7704),
#  ('lyres', 7703),
#  ('tawas', 7703),
#  ('bonds', 7702),
#  ...]

# %%
len([w for w in d if w[2] == 'r' and w[3] == 'e'])
# Out:
# 172
